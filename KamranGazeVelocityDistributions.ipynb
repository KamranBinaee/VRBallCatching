# %%
from __future__ import division

import PerformParser as pp
import pandas as pd
import numpy as np
from scipy import signal as sig
import performFun as pF

import bokeh.plotting as bkP
import bokeh.models as bkM
from bokeh.palettes import Spectral6
bkP.output_notebook() 

import cv2
import os
import scipy.io as sio
import matplotlib

# %matplotlib notebook
from ipywidgets import interact
import filterpy as fP
from bokeh.io import push_notebook

import Quaternion as qu

import plotly
from plotly.graph_objs import Scatter, Layout
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print plotly.__version__

plotly.offline.init_notebook_mode()

import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter, freqz
from scipy.fftpack import fft
from mpl_toolkits.mplot3d import Axes3D

bkP.output_notebook()

#bkP.output_file('timeSeries.html') 

#%pylab inline
#%matplotlib notebook

# %%
x0 = processedDataFrame.cycGazeVelocity.values
minValue = min(x0)
maxValue = max(x0)
trace1 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace1]#, trace2]
layout = go.Layout(
    title='Distribution of Pursuit angular gaze velocity over all 10 subjects all frames',
    xaxis=dict(
        title='Gaze Velocity [deg/sec]',
        range = [0, 300]
    ),
    yaxis=dict(
        title='p(Gaze Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
x0 = processedDataFrame.headVelocity.values
minValue = min(x0)
maxValue = max(x0)
trace1 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='orange',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace1]#, trace2]
layout = go.Layout(
    title='Distribution of angular head velocity over all 10 subjects all frames',
    xaxis=dict(
        title='Head Velocity [deg/sec]',
        range = [0, 300]
    ),
    yaxis=dict(
        title='p(Head Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
eyetoScreenDistance = 0.0725
x0 = (processedDataFrame.rotatedGazePoint.X.values) 
x0 = np.arctan2(x0,eyetoScreenDistance)* 180/np.pi
x1 = (processedDataFrame.rotatedGazePoint.Y.values)
x1 = np.arctan2(x1,eyetoScreenDistance)* 180/np.pi
minValue = min(x0)
maxValue = max(x0)
trace1 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Elevation Angle',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=0.2
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
minValue = min(x1)
maxValue = max(x1)
trace2 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Azimuth Angle',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=0.2
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace1, trace2]
layout = go.Layout(
    title='Distribution of gaze angle (Eye in Head) over all 10 subjects all frames',
    xaxis=dict(
        title='Gaze Angle (Eye In Head) [deg of VA]',
        range = [-30, 30]
    ),
    yaxis=dict(
        title='p(Gaze Angle)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

#list(processedDataFrame.columns)

# %%
eyetoScreenDistance = 0.0725
x0 = (processedDataFrame.gazePoint.X.values) 
x0 = np.arctan2(x0,eyetoScreenDistance)* 180/np.pi
x1 = (processedDataFrame.gazePoint.Y.values)
x1 = np.arctan2(x1,eyetoScreenDistance)* 180/np.pi
minValue = min(x0)
maxValue = max(x0)
trace1 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Elevation Angle',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=0.2
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=0.5
        )
    ),
    opacity=0.75
)
minValue = min(x1)
maxValue = max(x1)
trace2 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Azimuth Angle',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=0.2
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=0.5
        )
    ),
    opacity=0.75
)
data = [trace1, trace2]
layout = go.Layout(
    title='Distribution of gaze angle (Gaze In World) over all 10 subjects all frames',
    xaxis=dict(
        title='Gaze Angle (Gaze In World) [deg of VA]',
        range = [-50, 50]
    ),
    yaxis=dict(
        title='p(Gaze Angle)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

#list(processedDataFrame.columns)

# %%
x0 = processedDataFrame.cycGazeVelocity.values - processedDataFrame.ballVelocity.values
minValue = min(x0)
maxValue = max(x0)
trace1 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Difference Velocity',
    autobinx=False,
    xbins=dict(
        start=-200,#minValue,
        end=200,#maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace1]#, trace2]
layout = go.Layout(
    title='Distribution of Difference between Gaze & Ball Velocity over all subjects all frames',
    xaxis=dict(
        title='Difference Velocity [deg/sec]',
        range = [-200, 200]
    ),
    yaxis=dict(
        title='p(Difference Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
gazeVelocity_BD = np.array([], dtype=float)
gazeVelocity_PreBD = gazeVelocity_BD
gazeVelocity_PostBD = gazeVelocity_BD
gazeVelocity_atBallOff = processedDataFrame.cycGazeVelocity.values[ballOffIdx]
gazeVelocity_atBallOn = processedDataFrame.cycGazeVelocity.values[ballOnIdx]
for i in range(len(trialInfoDataFrame)):
    gazeVelocity_PreBD = np.hstack((gazeVelocity_PreBD, processedDataFrame.cycGazeVelocity.values[trialStartIdx[i]+15:ballOffIdx[i]+7]))
    gazeVelocity_BD = np.hstack((gazeVelocity_BD, processedDataFrame.cycGazeVelocity.values[ballOffIdx[i]+8:ballOnIdx[i]+7]))
    gazeVelocity_PostBD = np.hstack((gazeVelocity_PostBD, processedDataFrame.cycGazeVelocity.values[ballOnIdx[i]:ballCrossingIdx[i]]))

x0 = gazeVelocity_PreBD
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity Before Blank',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeVelocity_BD
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Velocity During Blank ',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeVelocity_PostBD
minValue = min(x2)
maxValue = max(x2)
trace2 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Velocity After Blank',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='yellow',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace0, trace1, trace2]
layout = go.Layout(
    title='Distribution of Gaze Velocity for different stages of the trial',
    xaxis=dict(
        title='Gaze Velocity [deg/sec]',
        range = [0, 200]
    ),
    yaxis=dict(
        title='p(Gaze Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
ballVelocity_BD = np.array([], dtype=float)
ballVelocity_PreBD = ballVelocity_BD
ballVelocity_PostBD = ballVelocity_BD

for i in range(len(trialInfoDataFrame)):
    ballVelocity_PreBD = np.hstack((ballVelocity_PreBD, processedDataFrame.ballVelocity.values[trialStartIdx[i]:ballOffIdx[i]]))
    ballVelocity_BD = np.hstack((ballVelocity_BD, processedDataFrame.ballVelocity.values[ballOffIdx[i]:ballOnIdx[i]]))
    ballVelocity_PostBD = np.hstack((ballVelocity_PostBD, processedDataFrame.ballVelocity.values[ballOnIdx[i]:ballCrossingIdx[i]]))

# %%
ballVelocity_BD = ballVelocity_BD#(ballVelocity_BD - gazeVelocity_BD)
ballVelocity_PreBD = ballVelocity_PreBD#(ballVelocity_PreBD - gazeVelocity_PreBD)
ballVelocity_PostBD = ballVelocity_PostBD#(ballVelocity_PostBD - gazeVelocity_PostBD)

x0 = ballVelocity_BD
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Ball Velocity Before Blank',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = ballVelocity_PreBD
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Ball Velocity During Blank ',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = ballVelocity_PostBD
minValue = min(x2)
maxValue = max(x2)
trace2 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Ball Velocity After Blank',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='yellow',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace0, trace1, trace2]
layout = go.Layout(
    title='Distribution of Ball Velocity for different stages of the trial',
    xaxis=dict(
        title='Ball Velocity [deg/sec]',
        range = [0, 200]
    ),
    yaxis=dict(
        title='p(Ball Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
gazeError_BDSucc = np.array([], dtype=float)
gazeError_PreBDSucc = gazeError_BDSucc
gazeError_PostBDSucc = gazeError_BDSucc

gazeError_BDMiss = np.array([], dtype=float)
gazeError_PreBDMiss = gazeError_BDSucc
gazeError_PostBDMiss = gazeError_BDSucc

for i in range(len(trialInfoDataFrame)):
    if ( trialInfoDataFrame.ballCaughtQ.values[i] == True ):
        gazeError_PreBDSucc = np.hstack((gazeError_PreBDSucc, processedDataFrame.gazeAngularError.values[trialStartIdx[i]:ballOffIdx[i]]))
        gazeError_BDSucc = np.hstack((gazeError_BDSucc, processedDataFrame.gazeAngularError.values[ballOffIdx[i]:ballOnIdx[i]]))
        gazeError_PostBDSucc = np.hstack((gazeError_PostBDSucc, processedDataFrame.gazeAngularError.values[ballOnIdx[i]:ballCrossingIdx[i]]))
    else:
        gazeError_PreBDMiss = np.hstack((gazeError_PreBDMiss, processedDataFrame.gazeAngularError.values[trialStartIdx[i]:ballOffIdx[i]]))
        gazeError_BDMiss = np.hstack((gazeError_BDMiss, processedDataFrame.gazeAngularError.values[ballOffIdx[i]:ballOnIdx[i]]))
        gazeError_PostBDMiss = np.hstack((gazeError_PostBDMiss, processedDataFrame.gazeAngularError.values[ballOnIdx[i]:ballCrossingIdx[i]]))

# %%
myBinSize = 0.2
x0 = gazeError_PreBDSucc
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Error Before Blank (Success)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=myBinSize
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeError_BDSucc
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Error During Blank (Success)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=myBinSize
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeError_PostBDSucc
minValue = min(x2)
maxValue = max(x2)
trace2 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Error After Blank (Success)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=myBinSize
    ),
    marker=dict(
        color='yellow',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x0 = gazeError_PreBDMiss
minValue = min(x0)
maxValue = max(x0)
trace3 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Error Before Blank (Miss)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=myBinSize
    ),
    marker=dict(
        color='cyan',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeError_BDMiss
minValue = min(x1)
maxValue = max(x1)
trace4 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Error During Blank (Miss)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=myBinSize
    ),
    marker=dict(
        color='purple',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeError_PostBDMiss
minValue = min(x2)
maxValue = max(x2)
trace5 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Error After Blank (Miss)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=myBinSize
    ),
    marker=dict(
        color='brown',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace0, trace1, trace2,
        trace3, trace4, trace5]
layout = go.Layout(
    title='Distribution of Gaze Error',
    xaxis=dict(
        title='Gaze Error [deg of VA]',
        range = [0, 15]
    ),
    yaxis=dict(
        title='p(Gaze Error)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
gazeVelocity_BDSucc = np.array([], dtype=float)
gazeVelocity_PreBDSucc = gazeVelocity_BDSucc
gazeVelocity_PostBDSucc = gazeVelocity_BDSucc

gazeVelocity_BDMiss = np.array([], dtype=float)
gazeVelocity_PreBDMiss = gazeVelocity_BDMiss
gazeVelocity_PostBDMiss = gazeVelocity_BDMiss

for i in range(len(trialInfoDataFrame)):
    if ( trialInfoDataFrame.ballCaughtQ.values[i] == True ):
        gazeVelocity_PreBDSucc = np.hstack((gazeVelocity_PreBDSucc, processedDataFrame.cycGazeVelocity.values[trialStartIdx[i]:ballOffIdx[i]]))
        gazeVelocity_BDSucc = np.hstack((gazeVelocity_BDSucc, processedDataFrame.cycGazeVelocity.values[ballOffIdx[i]:ballOnIdx[i]]))
        gazeVelocity_PostBDSucc = np.hstack((gazeVelocity_PostBDSucc, processedDataFrame.cycGazeVelocity.values[ballOnIdx[i]:ballCrossingIdx[i]]))
    else:
        gazeVelocity_PreBDMiss = np.hstack((gazeVelocity_PreBDMiss, processedDataFrame.cycGazeVelocity.values[trialStartIdx[i]:ballOffIdx[i]]))
        gazeVelocity_BDMiss = np.hstack((gazeVelocity_BDMiss, processedDataFrame.cycGazeVelocity.values[ballOffIdx[i]:ballOnIdx[i]]))
        gazeVelocity_PostBDMiss = np.hstack((gazeVelocity_PostBDMiss, processedDataFrame.cycGazeVelocity.values[ballOnIdx[i]:ballCrossingIdx[i]]))

# %%
x0 = gazeVelocity_PreBDSucc
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity Before Blank (Success)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeVelocity_BDSucc
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Velocity During Blank (Success)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeVelocity_PostBDSucc
minValue = min(x2)
maxValue = max(x2)
trace2 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Velocity After Blank (Success)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='yellow',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x0 = gazeVelocity_PreBDMiss
minValue = min(x0)
maxValue = max(x0)
trace3 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity Before Blank (Miss)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='cyan',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeVelocity_BDMiss
minValue = min(x1)
maxValue = max(x1)
trace4 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Velocity During Blank (Miss)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='purple',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeVelocity_PostBDMiss
minValue = min(x2)
maxValue = max(x2)
trace5 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Velocity After Blank (Miss)',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='brown',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace0, trace1, trace2,
        trace3, trace4, trace5]
layout = go.Layout(
    title='Distribution of Gaze Velocity for different stages of the "Success" & "Miss" trials',
    xaxis=dict(
        title='Gaze Velocity [deg/sec]',
        range = [0, 300]
    ),
    yaxis=dict(
        title='p(Gaze Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
gazeVelocity_BD = np.array([], dtype=float)
gazeVelocity_PreBD = gazeVelocity_BD
gazeVelocity_PostBD = gazeVelocity_BD
gazeVelocity_atBallOff = processedDataFrame.cycGazeVelocity.values[ballOffIdx]
gazeVelocity_atBallOn = processedDataFrame.cycGazeVelocity.values[ballOnIdx]

x0 = gazeVelocity_atBallOff
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity at Ball Off',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeVelocity_atBallOn
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Velocity at Ball On',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

data = [trace0, trace1]
layout = go.Layout(
    title='Distribution of Gaze Velocity at Ball On & Off Frames',
    xaxis=dict(
        title='Gaze Velocity [deg/sec]',
        range = [0, 300]
    ),
    yaxis=dict(
        title='p(Gaze Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
#np.unique(rawDataFrame.ballVel.Z.values)
gazeVelocity_BD = np.array([], dtype=float)
gazeVelocity_PreBD1 = gazeVelocity_BD
gazeVelocity_PreBD2 = gazeVelocity_BD
gazeVelocity_PreBD3 = gazeVelocity_BD

index1 = rawDataFrame.preBlankDur.index[rawDataFrame.preBlankDur.values == 0.6]
index2 = rawDataFrame.preBlankDur.index[rawDataFrame.preBlankDur.values == 0.8]
index3 = rawDataFrame.preBlankDur.index[rawDataFrame.preBlankDur.values == 1.0]

gazeVelocity_PreBD1 = processedDataFrame.cycGazeVelocity.values[index1]
gazeVelocity_PreBD2 = processedDataFrame.cycGazeVelocity.values[index2]
gazeVelocity_PreBD3 = processedDataFrame.cycGazeVelocity.values[index3]

x0 = gazeVelocity_PreBD1
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity for Pre-BD = 600 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeVelocity_PreBD2
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Velocity for Pre-BD = 800 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeVelocity_PreBD3
minValue = min(x2)
maxValue = max(x2)
trace2 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Velocity for Pre-BD = 1000 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='yellow',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace0, trace1, trace2]
layout = go.Layout(
    title='Distribution of Gaze Velocity for different Pre Blank Durations',
    xaxis=dict(
        title='Gaze Velocity [deg/sec]',
        range = [0, 300]
    ),
    yaxis=dict(
        title='p(Gaze Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
#np.unique(rawDataFrame.ballVel.Z.values)
gazeVelocity_BD = np.array([], dtype=float)
gazeVelocity_PreBD1 = gazeVelocity_BD
gazeVelocity_PreBD2 = gazeVelocity_BD
gazeVelocity_PreBD3 = gazeVelocity_BD

index1 = rawDataFrame.preBlankDur.index[rawDataFrame.postBlankDur.values == 0.3]
index2 = rawDataFrame.preBlankDur.index[rawDataFrame.postBlankDur.values == 0.4]
index3 = rawDataFrame.preBlankDur.index[rawDataFrame.postBlankDur.values == 0.5]

gazeVelocity_PreBD1 = processedDataFrame.cycGazeVelocity.values[index1]
gazeVelocity_PreBD2 = processedDataFrame.cycGazeVelocity.values[index2]
gazeVelocity_PreBD3 = processedDataFrame.cycGazeVelocity.values[index3]

x0 = gazeVelocity_PreBD1
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity for Post-BD = 300 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeVelocity_PreBD2
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Velocity for Post-BD = 400 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeVelocity_PreBD3
minValue = min(x2)
maxValue = max(x2)
trace2 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Velocity for Post-BD = 500 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='yellow',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace0, trace1, trace2]
layout = go.Layout(
    title='Distribution of Gaze Velocity for different Post Blank Durations',
    xaxis=dict(
        title='Gaze Velocity [deg/sec]',
        range = [0, 300]
    ),
    yaxis=dict(
        title='p(Gaze Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %%
#np.unique(rawDataFrame.ballVel.Z.values)
gazeVelocity_BD = np.array([], dtype=float)
gazeVelocity_PreBD1 = gazeVelocity_BD
gazeVelocity_PreBD2 = gazeVelocity_BD
gazeVelocity_PreBD3 = gazeVelocity_BD

index1 = rawDataFrame.preBlankDur.index[abs(rawDataFrame.ballTTC.values - 1.4) < 0.0001]
index2 = rawDataFrame.preBlankDur.index[abs(rawDataFrame.ballTTC.values - 1.7) < 0.0001]
index3 = rawDataFrame.preBlankDur.index[abs(rawDataFrame.ballTTC.values - 2.0) < 0.0001]

gazeVelocity_PreBD1 = processedDataFrame.cycGazeVelocity.values[index1]
gazeVelocity_PreBD2 = processedDataFrame.cycGazeVelocity.values[index2]
gazeVelocity_PreBD3 = processedDataFrame.cycGazeVelocity.values[index3]

x0 = gazeVelocity_PreBD1
minValue = min(x0)
maxValue = max(x0)
trace0 = go.Histogram(
    x=x0,
    histnorm='probability',
    name='Gaze Velocity for TTC = 1400 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='blue',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x1 = gazeVelocity_PreBD2
minValue = min(x1)
maxValue = max(x1)
trace1 = go.Histogram(
    x=x1,
    histnorm='probability',
    name='Gaze Velocity for TTC = 1700 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='red',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)

x2 = gazeVelocity_PreBD3
minValue = min(x2)
maxValue = max(x2)
trace2 = go.Histogram(
    x=x2,
    histnorm='probability',
    name='Gaze Velocity for TTC = 2000 [ms]',
    autobinx=False,
    xbins=dict(
        start=minValue,
        end=maxValue,
        size=1
    ),
    marker=dict(
        color='yellow',
        line=dict(
            color='grey',
            width=1
        )
    ),
    opacity=0.75
)
data = [trace0, trace1, trace2]
layout = go.Layout(
    title='Distribution of Gaze Velocity for different Post Blank Durations',
    xaxis=dict(
        title='Gaze Velocity [deg/sec]',
        range = [0, 300]
    ),
    yaxis=dict(
        title='p(Gaze Velocity)'
    ),
    barmode='overlay',
    bargap=0,
    bargroupgap=0
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
